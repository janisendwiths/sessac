# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()
# Out:
# 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\chromedriver_autoinstaller\\97\\chromedriver.exe'

# %%
browser = webdriver.Chrome()

# %%
# for i in range(1,11) :

#     browser.get("https://www1.president.go.kr/petitions/best?page=" + str(i))

#     soup = BeautifulSoup(.page_source, 'html.parser')

#     result_list = []

#     for i in soup.select("#cont_view > div.cs_area > div > div > div.board.text > div.b_list.category > div.bl_body > ul > li"):
#         print(i.find("div", class_="bl_subject").text[3:].strip())
#         result_list.append(i.find("div", class_="bl_subject").text[3:])

#     time.sleep(5)

# %%
result_list = []

# %%
result5_list =[]
browser.get("https://www1.president.go.kr/petitions/?c=0&only=2&page=5&order=1" )

soup = BeautifulSoup(browser.page_source, 'html.parser')

for i in soup.select("#cont_view > div.cs_area > div > div > div.ct_petitions > div.ct_petitions_area.ct_txt_left > div.ct_list1 > div.board.text > div.b_list.category.b_list2 > div.bl_body > ul > li > div"):
    print(i.find("div", class_="bl_subject").text[3:].strip())
    result5_list.append(i.find("div", class_="bl_subject").text[3:])
    time.sleep(1)

time.sleep(1)
# Out:
# 기본방역 수칙에도 맞지 않고 국민 상식에도 어긋나는 코로나19 대책 이제는  바꿔야합니다
# 보험사의 2차사고책임강력한처벌원합니다.
# 사실혼관계로 인한 재산분할 및 상속권 폐지 부탁드립니다.
# 충남 **시 유치원 어린이집 교육비 관련
# 인생을 송두리째 흔들어놓은 학부모. 보육교사의 인권을 존중해주세요.
# *****현장 지게차사고
# 상속세 탈루를 위해 편법을 동원하고 어머니와 형제들의 상속액을 모두 편취한 부산 **** 대표 *모씨를 고발합니다.

# %%
word_list = []

for text in result5_list :
    if "코로나" in text :
        text = "코로나"
    else :
        text = "제외"
    word_list.append(word)

# %%
print(word_list)
# Out:
# ['제외', '제외', '제외', '제외', '제외', '제외', '제외']

# %%
for i in range(1,11) :

    browser.get("https://www1.president.go.kr/petitions/?c=0&only=2&page="+ str(i) +"&order=1" )

    soup = BeautifulSoup(browser.page_source, 'html.parser')
    
    print(i)
    
    for i in soup.select("#cont_view > div.cs_area > div > div > div.ct_petitions > div.ct_petitions_area.ct_txt_left > div.ct_list1 > div.board.text > div.b_list.category.b_list2 > div.bl_body > ul > li > div"):
        print(i.find("div", class_="bl_subject").text[3:].strip())
        result_list.append(i.find("div", class_="bl_subject").text[3:])
        time.sleep(1)
    
    time.sleep(5)
# Out:
# 1
# JTBC 드라마 '설**'를 둘러싼 수많은 날조와 왜곡에 대한 진실
# 공인중개사도, 자영업자입니다.
# 방역패스를 예외 받을수 있는 범위를 확대하주세요.
# 공산당이나하는 3080+도심복합공공주도재개발 대상지  대구 남구 봉덕동 즉시 철회 요청
# 농촌체험마을도 대한민국 국민입니다.
# 어린이보호구역(school zone) 지정 가변화
# 드라마 설** 진실을 알려드립니다.
# 2
# 중학교와 주민 거주지, 그리고 독립기념관 바로 옆에 조성하려는 지정폐기물매립장을 막아주세요.
# 코로나로 생계마저 위협받는 전세버스 기사님들 좀 살려주세요
# 전라북도 정읍시 ***** 골프장 요금 유료화는 철회 되어야 합니다.
# 모두가 주목해야할 현실! 백신패스, 거리두기 이게 정말 맞나요?
# 국회의원 수당등에 관한법률은 위헌이므로 폐지청원합니다
# 왜 방역에 종교에만 관대합니까?
# 평등과 부의 재분배를 이유로 잘못된 길을 가고있는 국민연금을 바로잡아 주십시오.
# 3
# "성폭행범 누명을 쓴 제 딸을 도와주세요"
# 저희 아이들을 지켜주세요!!!!!
# SH의 비상식적이고 불통의 행태를 신고합니다.
# 팬데믹을 악용한 *** 경영진의 도덕성을 규탄한다
# ****** 최대주주이자 전 프로농구 감독이였던 ***씨의 임대료 갑질을 막아 주세요!
# “코로나19”와 거꾸로 가는 “민간직업훈련지원정책” (훈련비,훈련장려금 현실화)
# 맞아도 소리한번 지르지 못한 내 아들아. 엄마가 미안해..
# 4
# 대통령님...눈물로 호소합니다. 도와주세요
# 자영업자들을 제발 도와주세요
# 허위진단 과 의무기록 및 영상 위변조 혐의에 대한 형사고소 건의 조속한 진행을 촉구합니다.
# 해외입국자 자가격리 10일 다른방법으로 바꿔주세요
# 코로나백신주사사망
# 안일한 공무수행
# CCTV 법 개정으로 인한 교사들의 인권보호를 요구합니다
# 5
# 6
# 코로나 백신 성분 검증 및 현미경으로 미생물 유무 공개 방송 합시다
# ...

# %%
print(result_list)
# Out:
# ["JTBC 드라마 '설**'를 둘러싼 수많은 날조와 왜곡에 대한 진실", '공인중개사도, 자영업자입니다.', '방역패스를 예외 받을수 있는 범위를 확대하주세요.', '공산당이나하는 3080+도심복합공공주도재개발 대상지  대구 남구 봉덕동 즉시 철회 요청', '농촌체험마을도 대한민국 국민입니다.', '어린이보호구역(school zone) 지정 가변화', '드라마 설** 진실을 알려드립니다.', '중학교와 주민 거주지, 그리고 독립기념관 바로 옆에 조성하려는 지정폐기물매립장을 막아주세요.', '코로나로 생계마저 위협받는 전세버스 기사님들 좀 살려주세요', '전라북도 정읍시 ***** 골프장 요금 유료화는 철회 되어야 합니다.', '모두가 주목해야할 현실! 백신패스, 거리두기 이게 정말 맞나요?', '국회의원 수당등에 관한법률은 위헌이므로 폐지청원합니다', '왜 방역에 종교에만 관대합니까?', '평등과 부의 재분배를 이유로 잘못된 길을 가고있는 국민연금을 바로잡아 주십시오.', '"성폭행범 누명을 쓴 제 딸을 도와주세요"', '저희 아이들을 지켜주세요!!!!!', 'SH의 비상식적이고 불통의 행태를 신고합니다.', '팬데믹을 악용한 *** 경영진의 도덕성을 규탄한다', '****** 최대주주이자 전 프로농구 감독이였던 ***씨의 임대료 갑질을 막아 주세요!', '“코로나19”와 거꾸로 가는 “민간직업훈련지원정책” (훈련비,훈련장려금 현실화)', '맞아도 소리한번 지르지 못한 내 아들아. 엄마가 미안해..', '대통령님...눈물로 호소합니다. 도와주세요', '자영업자들을 제발 도와주세요', '허위진단 과 의무기록 및 영상 위변조 혐의에 대한 형사고소 건의 조속한 진행을 촉구합니다.', '해외입국자 자가격리 10일 다른방법으로 바꿔주세요', '코로나백신주사사망', '안일한 공무수행', 'CCTV 법 개정으로 인한 교사들의 인권보호를 요구합니다', '기본방역 수칙에도 맞지 않고 국민 상식에도 어긋나는 코로나19 대책 이제는  바꿔야합니다', '보험사의 2차사고책임강
# ...

# %%
date_list = []
for i in range(1,11) :

    browser.get("https://www1.president.go.kr/petitions/?c=0&only=2&page="+ str(i) +"&order=1" )

    soup = BeautifulSoup(browser.page_source, 'html.parser')
    
    print(i)
    
    for i in soup.select("#cont_view > div.cs_area > div > div > div.ct_petitions > div.ct_petitions_area.ct_txt_left > div.ct_list1 > div.board.text > div.b_list.category.b_list2 > div.bl_body > ul > li > div"):
        print(i.find("div", class_="bl_date light").text[7:].strip())
        date_list.append(i.find("div", class_="bl_date light").text[7:])
        time.sleep(1)
    
    time.sleep(1)
# Out:
# 1
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 3
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 4
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-20
# 2022-01-19
# 5
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 6
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 7
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 8
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 9
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 10
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19
# 2022-01-19

# %%
result_list = result_list + result5_list
print(len(result_list))
print(len(date_list))
# Out:
# 70
# 70

# %%
import pandas as pd
df = pd.DataFrame({'청원제목' : result_list,
                   '만료일' : date_list})

# %%
print(df)
# Out:
#                                                  청원제목         만료일
# 0               JTBC 드라마 '설**'를 둘러싼 수많은 날조와 왜곡에 대한 진실  2022-01-20
# 1                                    공인중개사도, 자영업자입니다.  2022-01-20
# 2                         방역패스를 예외 받을수 있는 범위를 확대하주세요.  2022-01-20
# 3    공산당이나하는 3080+도심복합공공주도재개발 대상지  대구 남구 봉덕동 즉시 철회 요청  2022-01-20
# 4                                 농촌체험마을도 대한민국 국민입니다.  2022-01-20
# 5                         어린이보호구역(school zone) 지정 가변화  2022-01-20
# 6                                 드라마 설** 진실을 알려드립니다.  2022-01-20
# 7   중학교와 주민 거주지, 그리고 독립기념관 바로 옆에 조성하려는 지정폐기물매립장을 막...  2022-01-20
# 8                    코로나로 생계마저 위협받는 전세버스 기사님들 좀 살려주세요  2022-01-20
# 9              전라북도 정읍시 ***** 골프장 요금 유료화는 철회 되어야 합니다.  2022-01-20
# 10                모두가 주목해야할 현실! 백신패스, 거리두기 이게 정말 맞나요?  2022-01-20
# 11                      국회의원 수당등에 관한법률은 위헌이므로 폐지청원합니다  2022-01-20
# 12                                  왜 방역에 종교에만 관대합니까?  2022-01-20
# ...

# %%
dummy1 = [df['청원제목'].str.contains('코로나|방역|아스트라제네카')]

# %%
pd.set_option('display.max_seq_items', None)

# %%
print(dummy1)
# Out:
# [0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63     True
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# ...
